# %%
import numpy as np
import pandas as pd
df=pd.read_csv('data_final.csv')
X=df.loc[:, ['Temperature', 'Addion_time', 'Mode','Reaction_time']]
X = (X-X.min())/(X.max()-X.min())
y= df.loc[:, [ 'Mn', 'PDI','Skewness','Kurtosis']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=1075)
kmeans=KMeans(n_clusters=5,random_state=50).fit(X_train)
centers = np.array(kmeans.cluster_centers_)
# Out:
# /root/miniconda3/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
data_index_new1=np.arange(0,453)
X_train.index=data_index_new1
y_train.index=data_index_new1

# %%
from sklearn.metrics import pairwise_distances_argmin_min
closest, _ = pairwise_distances_argmin_min(centers, X_train)

# %%
data_inital=pd.concat([X_train.iloc[closest,],y_train.iloc[closest,]],axis=1,join='outer')

# %%
X_train_init=data_inital.loc[:,['Temperature', 'Addion_time', 'Mode','Reaction_time']]
y_train_init=data_inital.loc[:,[ 'Mn', 'PDI','Skewness','Kurtosis']]

# %%
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.base import clone
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.utils import shuffle
from modAL.disagreement import max_std_sampling
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.uncertainty import entropy_sampling
from xgboost import XGBRegressor

# %%
def list_by_models(X,y):
    sklearn_list = [Ridge(), Lasso(), LinearRegression(),XGBRegressor(),RandomForestRegressor(n_estimators =50),RandomForestRegressor(n_estimators =100),KNeighborsRegressor(n_neighbors=2, weights='distance')]
    learner_list=[]
    for regressor_emcm in sklearn_list:
        learner=ActiveLearner(estimator=regressor_emcm, query_strategy=max_std_sampling, X_training=X, y_training=y)
        learner_list.append(learner)
    print(len(X))
    return learner_list

# %%
def list_by_models(X,y):
    sklearn_list = [Ridge(), Lasso(), LinearRegression(),XGBRegressor(),RandomForestRegressor(n_estimators =50),RandomForestRegressor(n_estimators =100),KNeighborsRegressor(n_neighbors=2, weights='distance')]
    learner_list=[]
    for regressor_emcm in sklearn_list:
        learner=ActiveLearner(estimator=regressor_emcm, query_strategy=max_std_sampling, X_training=X, y_training=y)
        learner_list.append(learner)
    print(len(X))
    return learner_list

# %%
from numpy.linalg import norm
def expected_model_change_maximization(regressor, learner_list, X_pool, n_instances=1):
    changes = []
    for x in X_pool:
        x = x.reshape(1, -1)
        change = 0
        x_norm = norm(x)
        y_hat = regressor.predict(x)[0]
        for learner in learner_list:
            y_p = learner.predict(x)[0]
            change += abs(y_hat - y_p) * x_norm
            #change += abs(y_hat - y_p)
        change /= len(learner_list)
        changes.append(change)
    changes=np.squeeze(changes)
    #print(changes)
    changes_sum=changes.sum(axis=1)
    #print(changes_sum)
    query_idx = changes_sum.argsort()[-n_instances:][::-1]
    return query_idx

# %%
X_train_beiyong=X_train
y_train_beiyong=y_train

# %%
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")
# search_best_score_list=[]
# for j in range(1,150):
#     regressor=RandomForestRegressor(n_estimators=j,random_state=66)
#     regressor.fit(X_train_init, y_train_init)
#     test_score=regressor.score(X_test, y_test)
#     search_best_score_list.append(test_score)
# best_score_index=search_best_score_list.index(max(search_best_score_list))
# j_best=best_score_index+1
regressor=XGBRegressor(n_estimators = 20, 
                   learning_rate = 0.05, 
                   max_depth=5,
                   random_state=66)
regressor.fit(X_train_init, y_train_init)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=20, n_jobs=None,
#              num_parallel_tree=None, random_state=66, ...)

# %%
data_final=data_inital#Inital data_final
test_score_list=[]
mean_squared_error_list=[]
inital_y_predict=regressor.predict(X_test)
mean_squared_error_list.append(metrics.mean_squared_error(y_test,inital_y_predict))
print('inital mse',metrics.mean_squared_error(y_test,inital_y_predict))
for i in range(1,101):
    print(len(X_train))
    if i==1:
        learner_list=list_by_models(X=X_train_init,y=y_train_init)
    else:
        learner_list=list_by_models(X=X_train_relabel,y=y_train_relabel)
    re_idx=expected_model_change_maximization(regressor, learner_list, X_train.values, n_instances=1)
    data_relable=pd.concat([X_train.iloc[re_idx,],y_train.iloc[re_idx,]],axis=1,join='outer')
    X_train=X_train.drop(re_idx)
    y_train=y_train.drop(re_idx)
    X_train=X_train.reset_index(drop=True)
    y_train=y_train.reset_index(drop=True)
    #data_final=pd.concat([data_inital,data_relable],axis=0,join='outer')
    data_final=pd.concat([data_final,data_relable],axis=0,join='outer')#iteration to update data_final
    #print(data_final)
    X_train_relabel=data_final.loc[:,['Temperature', 'Addion_time', 'Mode','Reaction_time']]
    y_train_relabel=data_final.loc[:,[ 'Mn', 'PDI','Skewness','Kurtosis']]
    #search_best_score_list=[]
    search_min_mse_list=[]
    for j in range(1,50):
        regressor=XGBRegressor(n_estimators = j, 
                   learning_rate = 0.05, 
                   max_depth=5,random_state=66)
        regressor.fit(X_train_relabel, y_train_relabel)
        #test_score=regressor.score(X_test, y_test)
        y_predict=regressor.predict(X_test)
        mse=metrics.mean_squared_error(y_test, y_predict)
        #search_best_score_list.append(test_score)
        search_min_mse_list.append(mse)
    #print( search_best_score_list)
    best_score_index=search_min_mse_list.index(min(search_min_mse_list))
    j_best=best_score_index+1
    regressor=XGBRegressor(n_estimators = j_best, 
                   learning_rate = 0.1, 
                   max_depth=5,random_state=66)
    regressor.fit(X_train_relabel, y_train_relabel)
    print("Testing Score:%f" % regressor.score(X_test, y_test))
    test_score_list.append(regressor.score(X_test, y_test))
    y_predict=regressor.predict(X_test)
    print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_predict))
    mean_squared_error_list.append(metrics.mean_squared_error(y_test, y_predict))
    r_error_all=(metrics.mean_absolute_error(y_predict,y_test))/np.mean(np.array(y_test))
    print('Related Error',r_error_all)
# Out:
# inital mse 56.96586216111706
# 453
# 5
# Testing Score:0.412992
# Mean Squared Error: 41.86650898404013
# Related Error 0.36435889147607
# 452
# 6
# Testing Score:0.335234
# Mean Squared Error: 35.31530003981896
# Related Error 0.3471886618684237
# 451
# 7
# Testing Score:0.254461
# Mean Squared Error: 55.3637222803099
# Related Error 0.4423144632175395
# 450
# 8
# Testing Score:0.037596
# Mean Squared Error: 67.92461360894288
# Related Error 0.4979509163007811
# 449
# 9
# Testing Score:0.713372
# Mean Squared Error: 29.867241132456847
# Related Error 0.26526564040445644
# 448
# 10
# Testing Score:0.808135
# Mean Squared Error: 9.4213771285196
# Related Error 0.20464540205529844
# 447
# 11
# Testing Score:0.742635
# Mean Squared Error: 8.461188186878097
# Related Error 0.2054065056753211
# 446
# 12
# Testing Score:0.732531
# Mean Squared Error: 6.98747116717885
# Related Error 0.19987030946304415
# 445
# 13
# Testing Score:0.714257
# Mean Squared Error: 6.682101069300169
# Related Error 0.20574186894643248
# 444
# 14
# Testing Score:0.625041
# Mean Squared Error: 29.890404563018603
# Related Error 0.3244809444166775
# 443
# 15
# Testing Score:0.750274
# Mean Squared Error: 8.450429776665487
# Related Error 0.20909121218561538
# 442
# 16
# Testing Score:0.752611
# Mean Squared Error: 6.932616569564699
# Related Error 0.20533287442022966
# 441
# 17
# Testing Score:0.744991
# Mean Squared Error: 7.467192255275611
# Related Error 0.21342074844895728
# 440
# 18
# Testing Score:0.715962
# Mean Squared Error: 6.583277249234637
# Related Error 0.20523105025733748
# 439
# 19
# Testing Score:0.699246
# Mean Squared Error: 7.2958664040488115
# Related Error 0.2186623942643115
# 438
# 20
# Testing Score:0.708119
# Mean Squared Error: 6.84457010991377
# Related Error 0.21288830671244885
# 437
# 21
# Testing Score:0.713241
# Mean Squared Error: 7.142127723038723
# Related Error 0.21270540972144625
# 436
# 22
# Testing Score:0.723324
# Mean Squared Error: 8.50785381658627
# Related Error 0.21796331823290918
# 435
# 23
# Testing Score:0.812432
# Mean Squared Error: 7.086128419940634
# Related Error 0.19879046001488132
# 434
# 24
# Testing Score:0.802905
# Mean Squared Error: 7.443476668415757
# Related Error 0.20671074064809322
# 433
# 25
# Testing Score:0.821740
# Mean Squared Error: 7.24281742485284
# Related Error 0.19956761300806003
# 432
# 26
# Testing Score:0.838936
# Mean Squared Error: 4.313975961355145
# Related Error 0.1713526098843843
# 431
# 27
# Testing Score:0.800953
# Mean Squared Error: 4.451512294086832
# Related Error 0.1832005581905196
# 430
# 28
# Testing Score:0.809029
# Mean Squared Error: 4.496869346255595
# Related Error 0.18023958058966658
# 429
# 29
# Testing Score:0.829558
# Mean Squared Error: 4.42288362538142
# Related Error 0.17931722209160572
# 428
# 30
# Testing Score:0.854347
# Mean Squared Error: 4.2294411861598284
# Related Error 0.17759041390714114
# 427
# 31
# Testing Score:0.858658
# Mean Squared Error: 3.805521034058649
# Related Error 0.16709631863188543
# 426
# 32
# Testing Score:0.853365
# Mean Squared Error: 3.918716300470001
# Related Error 0.1715712091380798
# 425
# 33
# Testing Score:0.876085
# Mean Squared Error: 3.446873097226451
# Related Error 0.1527187189718724
# 424
# 34
# Testing Score:0.878814
# Mean Squared Error: 3.701594736716239
# Related Error 0.15715889646297676
# 423
# 35
# Testing Score:0.887353
# Mean Squared Error: 3.467408978344312
# Related Error 0.15225267917313423
# 422
# 36
# Testing Score:0.893910
# Mean Squared Error: 3.5034098312440825
# Related Error 0.1497024106227846
# 421
# 37
# Testing Score:0.889748
# Mean Squared Error: 3.6735506246928904
# Related Error 0.15432757055195495
# 420
# 38
# Testing Score:0.886076
# Mean Squared Error: 2.5266890592322016
# Related Error 0.13330862084017667
# 419
# 39
# Testing Score:0.893254
# Mean Squared Error: 2.3810404042447098
# Related Error 0.12951065540347903
# 418
# 40
# Testing Score:0.898132
# Mean Squared Error: 2.499895107828973
# Related Error 0.12806514448894676
# 417
# 41
# Testing Score:0.890385
# Mean Squared Error: 2.724842669252355
# Related Error 0.13342211275415355
# 416
# 42
# Testing Score:0.892620
# Mean Squared Error: 2.6860053637605215
# Related Error 0.132400394891333
# 415
# 43
# Testing Score:0.888166
# Mean Squared Error: 2.6881171527918633
# Related Error 0.1332284962978268
# 414
# 44
# Testing Score:0.887969
# Mean Squared Error: 2.7872827709527215
# Related Error 0.13425229775461875
# 413
# 45
# Testing Score:0.891189
# Mean Squared Error: 3.1605549426184845
# Related Error 0.1398917822535945
# 412
# 46
# Testing Score:0.902350
# Mean Squared Error: 2.017947314348144
# Related Error 0.12326851023050972
# 411
# 47
# Testing Score:0.903990
# Mean Squared Error: 2.3131956707488204
# Related Error 0.12821041165566732
# 410
# 48
# Testing Score:0.945778
# Mean Squared Error: 1.6751761591915477
# Related Error 0.10457167762512651
# 409
# 49
# Testing Score:0.942192
# Mean Squared Error: 1.4632758714770746
# Related Error 0.10118662291422971
# 408
# 50
# Testing Score:0.936826
# Mean Squared Error: 1.7055535637754224
# Related Error 0.10762252262268142
# 407
# 51
# Testing Score:0.939877
# Mean Squared Error: 1.5003430810025657
# Related Error 0.10019289737194001
# 406
# 52
# Testing Score:0.941210
# Mean Squared Error: 1.620149038153374
# Related Error 0.10320137235993915
# 405
# 53
# Testing Score:0.944366
# Mean Squared Error: 1.488971766082641
# Related Error 0.10131728599203405
# 404
# 54
# Testing Score:0.939486
# Mean Squared Error: 1.5939248319281423
# Related Error 0.10266284638435504
# 403
# 55
# Testing Score:0.941063
# Mean Squared Error: 1.7440037477527612
# Related Error 0.10289671859155493
# 402
# 56
# Testing Score:0.945697
# Mean Squared Error: 1.7850641383974082
# Related Error 0.10428734846419924
# 401
# 57
# Testing Score:0.945284
# Mean Squared Error: 1.9072710556209949
# Related Error 0.10530756667810474
# 400
# 58
# Testing Score:0.944398
# Mean Squared Error: 2.0871092782945015
# Related Error 0.1097118755582374
# 399
# 59
# Testing Score:0.943198
# Mean Squared Error: 1.9585446656737537
# Related Error 0.10801079687166897
# 398
# 60
# Testing Score:0.940640
# Mean Squared Error: 2.127025536949557
# Related Error 0.1092422447233969
# 397
# 61
# Testing Score:0.946729
# Mean Squared Error: 1.9561500144172705
# Related Error 0.10666785787768039
# 396
# 62
# Testing Score:0.945418
# Mean Squared Error: 2.1638931397732244
# Related Error 0.11018174173204534
# 395
# 63
# Testing Score:0.959581
# Mean Squared Error: 1.7233129793731805
# Related Error 0.09915651199290079
# 394
# 64
# Testing Score:0.957659
# Mean Squared Error: 1.9030827206377952
# Related Error 0.10382763245017029
# 393
# 65
# Testing Score:0.958356
# Mean Squared Error: 1.8556755140744916
# Related Error 0.10103129636529613
# 392
# 66
# Testing Score:0.956205
# Mean Squared Error: 1.8168262208267214
# Related Error 0.10074778590594986
# 391
# 67
# Testing Score:0.957283
# Mean Squared Error: 1.8962757998243078
# Related Error 0.10232543069390358
# 390
# 68
# Testing Score:0.953368
# Mean Squared Error: 1.8813430680182217
# Related Error 0.10343433694353511
# 389
# 69
# Testing Score:0.955527
# Mean Squared Error: 1.8909843096035424
# Related Error 0.10245117985784746
# 388
# 70
# Testing Score:0.962093
# Mean Squared Error: 1.5988694296365558
# Related Error 0.09780603263719351
# 387
# 71
# Testing Score:0.960746
# Mean Squared Error: 1.6862911624244377
# Related Error 0.10158948170437367
# 386
# 72
# Testing Score:0.961096
# Mean Squared Error: 1.6756537945201933
# Related Error 0.0993278355555034
# 385
# 73
# Testing Score:0.959789
# Mean Squared Error: 1.6583640952345402
# Related Error 0.09903940763222292
# 384
# 74
# Testing Score:0.959928
# Mean Squared Error: 1.7363964343837952
# Related Error 0.0996284021576068
# 383
# 75
# Testing Score:0.960577
# Mean Squared Error: 1.9568557264434878
# Related Error 0.10275923929804066
# 382
# 76
# Testing Score:0.963426
# Mean Squared Error: 1.6969715896726545
# Related Error 0.09840181866844792
# 381
# 77
# Testing Score:0.960466
# Mean Squared Error: 1.6983359896175374
# Related Error 0.09981829682247453
# 380
# 78
# Testing Score:0.958377
# Mean Squared Error: 1.7560758396605518
# Related Error 0.10077660434119247
# 379
# 79
# Testing Score:0.960688
# Mean Squared Error: 1.7541026026545006
# Related Error 0.10048056640807457
# 378
# 80
# Testing Score:0.959919
# Mean Squared Error: 1.7098047394935907
# Related Error 0.09965066935737282
# 377
# 81
# Testing Score:0.963402
# Mean Squared Error: 1.689040669169362
# Related Error 0.09708661298613058
# 376
# 82
# Testing Score:0.961656
# Mean Squared Error: 1.3810957305546625
# Related Error 0.09304291484028679
# 375
# 83
# Testing Score:0.963015
# Mean Squared Error: 1.3286406765260517
# Related Error 0.09330497674851038
# 374
# 84
# Testing Score:0.964703
# Mean Squared Error: 1.3208088491155239
# Related Error 0.09144641625385795
# 373
# 85
# Testing Score:0.965167
# Mean Squared Error: 1.437978178429884
# Related Error 0.09373799227580433
# 372
# 86
# Testing Score:0.963873
# Mean Squared Error: 1.3762463286770072
# Related Error 0.09169405874241343
# 371
# 87
# Testing Score:0.961613
# Mean Squared Error: 1.2203331692566033
# Related Error 0.08851460905290419
# 370
# 88
# Testing Score:0.960563
# Mean Squared Error: 1.1554539471676941
# Related Error 0.08655077325095187
# 369
# 89
# Testing Score:0.963923
# Mean Squared Error: 1.3020705081583233
# Related Error 0.09081841219928626
# 368
# 90
# Testing Score:0.964842
# Mean Squared Error: 1.2869311451338983
# Related Error 0.09069712703893197
# 367
# 91
# Testing Score:0.963944
# Mean Squared Error: 1.3325296098710853
# Related Error 0.0910164349596505
# 366
# 92
# Testing Score:0.963317
# Mean Squared Error: 1.3318467512787002
# Related Error 0.09099664402602277
# 365
# 93
# Testing Score:0.962634
# Mean Squared Error: 1.329046923157811
# Related Error 0.09184462408444968
# 364
# 94
# Testing Score:0.966551
# Mean Squared Error: 1.1102244320770573
# Related Error 0.08609030473373139
# 363
# 95
# Testing Score:0.965409
# Mean Squared Error: 1.2735763934312974
# Related Error 0.08762209430885129
# 362
# 96
# Testing Score:0.967670
# Mean Squared Error: 1.1358548983261094
# Related Error 0.08464135872974302
# 361
# 97
# Testing Score:0.964943
# Mean Squared Error: 1.3778708325471603
# Related Error 0.09001524037266274
# 360
# 98
# Testing Score:0.965317
# Mean Squared Error: 1.314539952287055
# Related Error 0.08851052789927556
# 359
# 99
# Testing Score:0.966070
# Mean Squared Error: 1.311610513921972
# Related Error 0.0884557262341515
# 358
# 100
# Testing Score:0.966975
# Mean Squared Error: 1.122015432813024
# Related Error 0.08384254092628787
# 357
# 101
# Testing Score:0.966399
# Mean Squared Error: 1.2315148967434313
# Related Error 0.08690181138216796
# 356
# 102
# Testing Score:0.965663
# Mean Squared Error: 1.2584302978467683
# Related Error 0.08558620847500222
# 355
# 103
# Testing Score:0.967992
# Mean Squared Error: 1.0375993966465653
# Related Error 0.07980864740856841
# 354
# 104
# Testing Score:0.969417
# Mean Squared Error: 1.0088831959122673
# Related Error 0.07900536098600631
